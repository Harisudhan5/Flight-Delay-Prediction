# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights=pd.read_csv('C:/Users/HARISUDHAN/Downloads/archive (11)/flights.csv')
flights=flights.sample(n=100000)
flights.head(11)
# Out:
# C:\Users\HARISUDHAN\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 3483269  2015      8    5            3      MQ           3387      N689MQ
# 5476688  2015     12    9            3      DL            442      N712TW
# 1746943  2015      4   22            3      DL           2132      N369NW
# 2186790  2015      5   19            2      MQ           3697      N534MQ
# 1905712  2015      5    2            6      OO           5316      N824AS
# 1917806  2015      5    2            6      AA            113      N3FSAA
# 2594601  2015      6   13            6      OO           2839      N498CA
# 1322096  2015      3   26            4      WN            169      N240WN
# 268451   2015      1   18            7      OO           2594      N417SW
# 3918663  2015      8   31            1      DL           1237      N366NB
# 1157469  2015      3   16            1      NK            450      N622NK
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 3483269            GSP                 DFW                 1120  ...
# 5476688            JFK                 LAX                 1925  ...
# 1746943            ATL                 SAT                  944  ...
# 2186790            ELP                 ORD                 1325  ...
# 1905712            MRY                 LAX                  540  ...
# 1917806            MIA                 DEN                 2000  ...
# 2594601            ICT                 ORD                 1215  ...
# 1322096            SAN                 SMF                 2155  ...
# 268451             SMF                 LAX                 1545  ...
# 3918663            DTW                 BOS                 1935  ...
# 1157469            FLL                 PBG                 2145  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 3483269        1247.0          -11.0         0          0
# 5476688        2228.0          -41.0         0          0
# 1746943        1112.0          -11.0         0          0
# 2186790        1718.0          -13.0         0          0
# 1905712         633.0          -26.0         0          0
# 1917806        2226.0           -2.0         0          0
# 2594601        1402.0          -11.0         0          0
# 1322096        2318.0          -22.0         0          0
# 268451         1706.0           -8.0         0          0
# 3918663        2133.0            4.0         0          0
# 1157469         107.0           12.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 3483269                  NaN               NaN             NaN            NaN
# 5476688                  NaN               NaN             NaN            NaN
# 1746943                  NaN               NaN             NaN            NaN
# 2186790                  NaN               NaN             NaN            NaN
# 1905712                  NaN               NaN             NaN            NaN
# 1917806                  NaN               NaN             NaN            NaN
# 2594601                  NaN               NaN             NaN            NaN
# 1322096                  NaN               NaN             NaN            NaN
# 268451                   NaN               NaN             NaN            NaN
# 3918663                  NaN               NaN             NaN            NaN
# 1157469                  NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 3483269                  NaN            NaN
# 5476688                  NaN            NaN
# 1746943                  NaN            NaN
# 2186790                  NaN            NaN
# 1905712                  NaN            NaN
# 1917806                  NaN            NaN
# 2594601                  NaN            NaN
# 1322096                  NaN            NaN
# 268451                   NaN            NaN
# 3918663                  NaN            NaN
# 1157469                  NaN            NaN
#
# [11 rows x 31 columns]

# %%
flights.shape
# Out:
# (100000, 31)

# %%
flights.isnull().sum()
# Out:
# YEAR                       0
# MONTH                      0
# DAY                        0
# DAY_OF_WEEK                0
# AIRLINE                    0
# FLIGHT_NUMBER              0
# TAIL_NUMBER              238
# ORIGIN_AIRPORT             0
# DESTINATION_AIRPORT        0
# SCHEDULED_DEPARTURE        0
# DEPARTURE_TIME          1422
# DEPARTURE_DELAY         1422
# TAXI_OUT                1466
# WHEELS_OFF              1466
# SCHEDULED_TIME             0
# ELAPSED_TIME            1738
# AIR_TIME                1738
# DISTANCE                   0
# WHEELS_ON               1523
# TAXI_IN                 1523
# SCHEDULED_ARRIVAL          0
# ARRIVAL_TIME            1523
# ARRIVAL_DELAY           1738
# DIVERTED                   0
# CANCELLED                  0
# CANCELLATION_REASON    98517
# AIR_SYSTEM_DELAY       81834
# SECURITY_DELAY         81834
# AIRLINE_DELAY          81834
# LATE_AIRCRAFT_DELAY    81834
# WEATHER_DELAY          81834
# dtype: int64

# %%
sns.countplot(x='CANCELLATION_REASON',data=flights)     # Reason for Cancellation of flight: A - Airline/Carrier; B - Weather; C - National Air System; D - Security
# Out:
# <AxesSubplot:xlabel='CANCELLATION_REASON', ylabel='count'>

# %%
sns.countplot(x="MONTH",hue="CANCELLATION_REASON",data=flights)
# Out:
# <AxesSubplot:xlabel='MONTH', ylabel='count'>

# %%
plt.figure(figsize=(10, 10))
axis = sns.countplot(x=flights['ORIGIN_AIRPORT'], data =flights, order=flights['ORIGIN_AIRPORT'].value_counts().iloc[:20].index)
axis.set_xticklabels(axis.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()

# %%
axis = plt.subplots(figsize=(20,14))
sns.heatmap(flights.corr(),annot = True)
plt.show()

# %%
corr=flights.corr()
corr
# Out:
#                      YEAR     MONTH       DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# YEAR                  NaN       NaN       NaN          NaN            NaN
# MONTH                 NaN  1.000000  0.005905    -0.009516      -0.019912
# DAY                   NaN  0.005905  1.000000     0.003280      -0.000033
# DAY_OF_WEEK           NaN -0.009516  0.003280     1.000000       0.011385
# FLIGHT_NUMBER         NaN -0.019912 -0.000033     0.011385       1.000000
# SCHEDULED_DEPARTURE   NaN -0.001856  0.004013     0.005324      -0.008744
# DEPARTURE_TIME        NaN -0.005599  0.003344     0.002793      -0.005088
# DEPARTURE_DELAY       NaN -0.024946  0.004122    -0.011762      -0.010864
# TAXI_OUT              NaN -0.017977  0.000349    -0.023176       0.048653
# WHEELS_OFF            NaN -0.005400  0.002538     0.000566       0.001675
# SCHEDULED_TIME        NaN  0.015594  0.002375     0.011173      -0.318823
# ELAPSED_TIME          NaN  0.004848  0.000218     0.007221      -0.307292
# AIR_TIME              NaN  0.006941  0.000205     0.010250      -0.320680
# DISTANCE              NaN  0.015168  0.002754     0.013102      -0.331835
# WHEELS_ON             NaN -0.005669 -0.001945     0.005638      -0.009924
# TAXI_IN               NaN  0.003406 -0.000858     0.000352      -0.015173
# SCHEDULED_ARRIVAL     NaN -0.005534 -0.000931     0.006947      -0.018916
# ARRIVAL_TIME          NaN -0.007552 -0.001973     0.006449      -0.007166
# ARRIVAL_DELAY         NaN -0.041734  0.000249    -0.018051       0.017953
# DIVERTED              NaN -0.000066  0.001338     0.001581       0.002510
# CANCELLED             NaN -0.058073 -0.005905    -0.025916       0.039760
# AIR_SYSTEM_DELAY      NaN -0.004368 -0.001696    -0.028557      -0.013319
# SECURITY_DELAY        NaN  0.012113 -0.002437     0.011471      -0.003961
# AIRLINE_DELAY         NaN  0.009331  0.006546     0.000844      -0.007618
# LATE_AIRCRAFT_DELAY   NaN  0.012085  0.007725    -0.007535       0.019754
# WEATHER_DELAY         NaN -0.018150  0.015401     0.005212       0.000964
#
#                      SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  \
# YEAR                                 NaN             NaN              NaN
# MONTH                          -0.001856       -0.005599        -0.024946
# DAY                             0.004013        0.003344         0.004122
# DAY_OF_WEEK                     0.005324        0.002793        -0.011762
# FLIGHT_NUMBER                  -0.008744       -0.005088        -0.010864
# SCHEDULED_DEPARTURE             1.000000        0.964947         0.114806
# DEPARTURE_TIME                  0.964947        1.000000         0.168569
# DEPARTURE_DELAY                 0.114806        0.168569         1.000000
# TAXI_OUT                        0.009063        0.016479         0.053595
# WHEELS_OFF                      0.938275        0.971112         0.158975
# SCHEDULED_TIME                 -0.013206       -0.018008         0.028390
# ELAPSED_TIME                   -0.013830       -0.018512         0.030654
# AIR_TIME                       -0.011967       -0.018010         0.023783
# DISTANCE                       -0.005806       -0.013466         0.024232
# WHEELS_ON                       0.655222        0.673498         0.055406
# TAXI_IN                        -0.044048       -0.039721         0.015152
# SCHEDULED_ARRIVAL               0.706620        0.710206         0.103727
# ARRIVAL_TIME                    0.631300        0.648723         0.046752
# ARRIVAL_DELAY                   0.106272        0.158151         0.945582
# DIVERTED                       -0.005517       -0.002069         0.036364
# CANCELLED                       0.012203        0.000994         0.029808
# AIR_SYSTEM_DELAY               -0.065518       -0.025386         0.068751
# SECURITY_DELAY                 -0.000810        0.002204        -0.001028
# AIRLINE_DELAY                  -0.074449       -0.033105         0.649967
# LATE_AIRCRAFT_DELAY             0.160777        0.178711         0.542013
# WEATHER_DELAY                  -0.007475        0.001333         0.250632
#
#                      TAXI_OUT  WHEELS_OFF  ...  SCHEDULED_ARRIVAL  \
# YEAR                      NaN         NaN  ...                NaN
# MONTH               -0.017977   -0.005400  ...          -0.005534
# DAY                  0.000349    0.002538  ...          -0.000931
# DAY_OF_WEEK         -0.023176    0.000566  ...           0.006947
# FLIGHT_NUMBER        0.048653    0.001675  ...          -0.018916
# SCHEDULED_DEPARTURE  0.009063    0.938275  ...           0.706620
# DEPARTURE_TIME       0.016479    0.971112  ...           0.710206
# DEPARTURE_DELAY      0.053595    0.158975  ...           0.103727
# TAXI_OUT             1.000000    0.040809  ...           0.027614
# WHEELS_OFF           0.040809    1.000000  ...           0.721154
# SCHEDULED_TIME       0.111929   -0.025551  ...           0.033808
# ELAPSED_TIME         0.206173   -0.023952  ...           0.033662
# AIR_TIME             0.087298   -0.026678  ...           0.031760
# DISTANCE             0.071288   -0.024690  ...           0.029067
# WHEELS_ON            0.029231    0.693903  ...           0.870983
# TAXI_IN              0.007271   -0.038780  ...          -0.007709
# SCHEDULED_ARRIVAL    0.027614    0.721154  ...           1.000000
# ARRIVAL_TIME         0.026724    0.669076  ...           0.862360
# ARRIVAL_DELAY        0.222420    0.152941  ...           0.095261
# DIVERTED             0.016361   -0.000827  ...           0.002451
# CANCELLED            0.010630    0.003930  ...           0.008586
# AIR_SYSTEM_DELAY     0.384478   -0.005699  ...          -0.026481
# SECURITY_DELAY      -0.006923    0.002641  ...           0.004767
# AIRLINE_DELAY       -0.071781   -0.041717  ...          -0.052701
# LATE_AIRCRAFT_DELAY -0.129324    0.147449  ...           0.112130
# WEATHER_DELAY        0.058817   -0.006816  ...          -0.004188
#
#                      ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# YEAR                          NaN            NaN       NaN        NaN
# MONTH                   -0.007552      -0.041734 -0.000066  -0.058073
# DAY                     -0.001973       0.000249  0.001338  -0.005905
# DAY_OF_WEEK              0.006449      -0.018051  0.001581  -0.025916
# FLIGHT_NUMBER           -0.007166       0.017953  0.002510   0.039760
# SCHEDULED_DEPARTURE      0.631300       0.106272 -0.005517   0.012203
# DEPARTURE_TIME           0.648723       0.158151 -0.002069   0.000994
# DEPARTURE_DELAY          0.046752       0.945582  0.036364   0.029808
# TAXI_OUT                 0.026724       0.222420  0.016361   0.010630
# WHEELS_OFF               0.669076       0.152941 -0.000827   0.003930
# SCHEDULED_TIME           0.023548      -0.029750  0.016789  -0.027374
# ELAPSED_TIME             0.024789       0.028677       NaN        NaN
# AIR_TIME                 0.022031      -0.007257       NaN        NaN
# DISTANCE                 0.018236      -0.025522  0.015988  -0.032167
# WHEELS_ON                0.971934       0.055221 -0.001945        NaN
# TAXI_IN                  0.002762       0.117247  0.034259        NaN
# SCHEDULED_ARRIVAL        0.862360       0.095261  0.002451   0.008586
# ARRIVAL_TIME             1.000000       0.047059 -0.000532        NaN
# ARRIVAL_DELAY            0.047059       1.000000       NaN        NaN
# DIVERTED                -0.000532            NaN  1.000000  -0.006204
# CANCELLED                     NaN            NaN -0.006204   1.000000
# AIR_SYSTEM_DELAY         0.013296       0.221866       NaN        NaN
# SECURITY_DELAY           0.010048      -0.002292       NaN        NaN
# AIRLINE_DELAY           -0.068407       0.638776       NaN        NaN
# LATE_AIRCRAFT_DELAY     -0.026673       0.509345       NaN        NaN
# WEATHER_DELAY           -0.029691       0.271020       NaN        NaN
#
#                      AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# YEAR                              NaN             NaN            NaN
# MONTH                       -0.004368        0.012113       0.009331
# DAY                         -0.001696       -0.002437       0.006546
# DAY_OF_WEEK                 -0.028557        0.011471       0.000844
# FLIGHT_NUMBER               -0.013319       -0.003961      -0.007618
# SCHEDULED_DEPARTURE         -0.065518       -0.000810      -0.074449
# DEPARTURE_TIME              -0.025386        0.002204      -0.033105
# DEPARTURE_DELAY              0.068751       -0.001028       0.649967
# TAXI_OUT                     0.384478       -0.006923      -0.071781
# WHEELS_OFF                  -0.005699        0.002641      -0.041717
# SCHEDULED_TIME               0.034081       -0.005764       0.038002
# ELAPSED_TIME                 0.161694       -0.006629       0.001907
# AIR_TIME                     0.060556       -0.004878       0.022263
# DISTANCE                     0.016237       -0.004701       0.036448
# WHEELS_ON                    0.009191        0.010468      -0.067024
# TAXI_IN                      0.255485       -0.005429      -0.047786
# SCHEDULED_ARRIVAL           -0.026481        0.004767      -0.052701
# ARRIVAL_TIME                 0.013296        0.010048      -0.068407
# ARRIVAL_DELAY                0.221866       -0.002292       0.638776
# DIVERTED                          NaN             NaN            NaN
# CANCELLED                         NaN             NaN            NaN
# AIR_SYSTEM_DELAY             1.000000       -0.013170      -0.123092
# SECURITY_DELAY              -0.013170        1.000000      -0.012517
# AIRLINE_DELAY               -0.123092       -0.012517       1.000000
# LATE_AIRCRAFT_DELAY         -0.151131       -0.010147      -0.094559
# WEATHER_DELAY               -0.003219       -0.005918      -0.047556
#
#                      LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# YEAR                                 NaN            NaN
# MONTH                           0.012085      -0.018150
# DAY                             0.007725       0.015401
# DAY_OF_WEEK                    -0.007535       0.005212
# FLIGHT_NUMBER                   0.019754       0.000964
# SCHEDULED_DEPARTURE             0.160777      -0.007475
# DEPARTURE_TIME                  0.178711       0.001333
# DEPARTURE_DELAY                 0.542013       0.250632
# TAXI_OUT                       -0.129324       0.058817
# WHEELS_OFF                      0.147449      -0.006816
# SCHEDULED_TIME                 -0.046325       0.001012
# ELAPSED_TIME                   -0.094022       0.008710
# AIR_TIME                       -0.065804      -0.002936
# DISTANCE                       -0.045239      -0.004697
# WHEELS_ON                      -0.017632      -0.027123
# TAXI_IN                        -0.052787       0.001261
# SCHEDULED_ARRIVAL               0.112130      -0.004188
# ARRIVAL_TIME                   -0.026673      -0.029691
# ARRIVAL_DELAY                   0.509345       0.271020
# DIVERTED                             NaN            NaN
# CANCELLED                            NaN            NaN
# AIR_SYSTEM_DELAY               -0.151131      -0.003219
# SECURITY_DELAY                 -0.010147      -0.005918
# AIRLINE_DELAY                  -0.094559      -0.047556
# LATE_AIRCRAFT_DELAY             1.000000      -0.016704
# WEATHER_DELAY                  -0.016704       1.000000
#
# [26 rows x 26 columns]

# %%
variables_to_remove=["YEAR","FLIGHT_NUMBER","TAIL_NUMBER","DEPARTURE_TIME","TAXI_OUT","WHEELS_OFF","ELAPSED_TIME","AIR_TIME","WHEELS_ON","TAXI_IN","ARRIVAL_TIME","DIVERTED","CANCELLED","CANCELLATION_REASON","AIR_SYSTEM_DELAY", "SECURITY_DELAY","AIRLINE_DELAY","LATE_AIRCRAFT_DELAY","WEATHER_DELAY","SCHEDULED_TIME","SCHEDULED_ARRIVAL"]
flights.drop(variables_to_remove,axis=1,inplace= True)
flights.columns
# Out:
# Index(['MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_DELAY',
#        'DISTANCE', 'ARRIVAL_DELAY'],
#       dtype='object')

# %%
flights.shape
# Out:
# (100000, 10)

# %%
airport = pd.read_csv('C:/Users/HARISUDHAN/Downloads/archive (11)/airports.csv')
airport.head(5)
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
flights.loc[~flights.ORIGIN_AIRPORT.isin(airport.IATA_CODE.values),'ORIGIN_AIRPORT']='OTHER'
flights.loc[~flights.DESTINATION_AIRPORT.isin(airport.IATA_CODE.values),'DESTINATION_AIRPORT']='OTHER'
flights
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 3483269      8    5            3      MQ            GSP                 DFW
# 5476688     12    9            3      DL            JFK                 LAX
# 1746943      4   22            3      DL            ATL                 SAT
# 2186790      5   19            2      MQ            ELP                 ORD
# 1905712      5    2            6      OO            MRY                 LAX
# ...        ...  ...          ...     ...            ...                 ...
# 2560053      6   11            4      DL            PNS                 ATL
# 2233224      5   22            5      UA            IAH                 LAS
# 1736506      4   21            2      DL            DTW                 MKE
# 3682165      8   17            1      WN            ATL                 MDW
# 4425504     10    3            6      HA          OTHER               OTHER
#
#          SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY
# 3483269                 1120             -6.0       862          -11.0
# 5476688                 1925              1.0      2475          -41.0
# 1746943                  944             -3.0       874          -11.0
# 2186790                 1325             13.0      1236          -13.0
# 1905712                  540             -3.0       266          -26.0
# ...                      ...              ...       ...            ...
# 2560053                 1145             -7.0       271          -27.0
# 2233224                  900              2.0      1222            0.0
# 1736506                 1545              0.0       237            5.0
# 3682165                  935             22.0       591            7.0
# 4425504                 1253             10.0       163           14.0
#
# [100000 rows x 10 columns]

# %%
print(flights.ORIGIN_AIRPORT.nunique())
print(flights.DESTINATION_AIRPORT.nunique())
print(flights.AIRLINE.nunique())
# Out:
# 317
# 323
# 14

# %%
flights=flights.dropna()
flights.head(10)
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 3483269      8    5            3      MQ            GSP                 DFW
# 5476688     12    9            3      DL            JFK                 LAX
# 1746943      4   22            3      DL            ATL                 SAT
# 2186790      5   19            2      MQ            ELP                 ORD
# 1905712      5    2            6      OO            MRY                 LAX
# 1917806      5    2            6      AA            MIA                 DEN
# 2594601      6   13            6      OO            ICT                 ORD
# 1322096      3   26            4      WN            SAN                 SMF
# 268451       1   18            7      OO            SMF                 LAX
# 3918663      8   31            1      DL            DTW                 BOS
#
#          SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY
# 3483269                 1120             -6.0       862          -11.0
# 5476688                 1925              1.0      2475          -41.0
# 1746943                  944             -3.0       874          -11.0
# 2186790                 1325             13.0      1236          -13.0
# 1905712                  540             -3.0       266          -26.0
# 1917806                 2000             10.0      1709           -2.0
# 2594601                 1215             -1.0       588          -11.0
# 1322096                 2155              1.0       480          -22.0
# 268451                  1545             -1.0       373           -8.0
# 3918663                 1935              6.0       632            4.0

# %%
flights.shape
# Out:
# (98262, 10)

# %%
df=pd.DataFrame(flights)
df['DAY_OF_WEEK']= df['DAY_OF_WEEK'].apply(str)
df["DAY_OF_WEEK"].replace({"1":"SUNDAY", "2": "MONDAY", "3": "TUESDAY", "4":"WEDNESDAY", "5":"THURSDAY", "6":"FRIDAY", "7":"SATURDAY"},inplace=True)
flights
# Out:
#          MONTH  DAY DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 3483269      8    5     TUESDAY      MQ            GSP                 DFW
# 5476688     12    9     TUESDAY      DL            JFK                 LAX
# 1746943      4   22     TUESDAY      DL            ATL                 SAT
# 2186790      5   19      MONDAY      MQ            ELP                 ORD
# 1905712      5    2      FRIDAY      OO            MRY                 LAX
# ...        ...  ...         ...     ...            ...                 ...
# 2560053      6   11   WEDNESDAY      DL            PNS                 ATL
# 2233224      5   22    THURSDAY      UA            IAH                 LAS
# 1736506      4   21      MONDAY      DL            DTW                 MKE
# 3682165      8   17      SUNDAY      WN            ATL                 MDW
# 4425504     10    3      FRIDAY      HA          OTHER               OTHER
#
#          SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY
# 3483269                 1120             -6.0       862          -11.0
# 5476688                 1925              1.0      2475          -41.0
# 1746943                  944             -3.0       874          -11.0
# 2186790                 1325             13.0      1236          -13.0
# 1905712                  540             -3.0       266          -26.0
# ...                      ...              ...       ...            ...
# 2560053                 1145             -7.0       271          -27.0
# 2233224                  900              2.0      1222            0.0
# 1736506                 1545              0.0       237            5.0
# 3682165                  935             22.0       591            7.0
# 4425504                 1253             10.0       163           14.0
#
# [98262 rows x 10 columns]

# %%
dums = ['AIRLINE','ORIGIN_AIRPORT','DESTINATION_AIRPORT','DAY_OF_WEEK']
df_cat=pd.get_dummies(df[dums],drop_first=True)
df_cat
# Out:
#          AIRLINE_AS  AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  AIRLINE_F9  \
# 3483269           0           0           0           0           0
# 5476688           0           0           1           0           0
# 1746943           0           0           1           0           0
# 2186790           0           0           0           0           0
# 1905712           0           0           0           0           0
# ...             ...         ...         ...         ...         ...
# 2560053           0           0           1           0           0
# 2233224           0           0           0           0           0
# 1736506           0           0           1           0           0
# 3682165           0           0           0           0           0
# 4425504           0           0           0           0           0
#
#          AIRLINE_HA  AIRLINE_MQ  AIRLINE_NK  AIRLINE_OO  AIRLINE_UA  ...  \
# 3483269           0           1           0           0           0  ...
# 5476688           0           0           0           0           0  ...
# 1746943           0           0           0           0           0  ...
# 2186790           0           1           0           0           0  ...
# 1905712           0           0           0           1           0  ...
# ...             ...         ...         ...         ...         ...  ...
# 2560053           0           0           0           0           0  ...
# 2233224           0           0           0           0           1  ...
# 1736506           0           0           0           0           0  ...
# 3682165           0           0           0           0           0  ...
# 4425504           1           0           0           0           0  ...
#
#          DESTINATION_AIRPORT_WYS  DESTINATION_AIRPORT_XNA  \
# 3483269                        0                        0
# 5476688                        0                        0
# 1746943                        0                        0
# 2186790                        0                        0
# 1905712                        0                        0
# ...                          ...                      ...
# 2560053                        0                        0
# 2233224                        0                        0
# 1736506                        0                        0
# 3682165                        0                        0
# 4425504                        0                        0
#
#          DESTINATION_AIRPORT_YAK  DESTINATION_AIRPORT_YUM  DAY_OF_WEEK_MONDAY  \
# 3483269                        0                        0                   0
# 5476688                        0                        0                   0
# 1746943                        0                        0                   0
# 2186790                        0                        0                   1
# 1905712                        0                        0                   0
# ...                          ...                      ...                 ...
# 2560053                        0                        0                   0
# 2233224                        0                        0                   0
# 1736506                        0                        0                   1
# 3682165                        0                        0                   0
# 4425504                        0                        0                   0
#
#          DAY_OF_WEEK_SATURDAY  DAY_OF_WEEK_SUNDAY  DAY_OF_WEEK_THURSDAY  \
# 3483269                     0                   0                     0
# 5476688                     0                   0                     0
# 1746943                     0                   0                     0
# 2186790                     0                   0                     0
# 1905712                     0                   0                     0
# ...                       ...                 ...                   ...
# 2560053                     0                   0                     0
# 2233224                     0                   0                     1
# 1736506                     0                   0                     0
# 3682165                     0                   1                     0
# 4425504                     0                   0                     0
#
#          DAY_OF_WEEK_TUESDAY  DAY_OF_WEEK_WEDNESDAY
# 3483269                    1                      0
# 5476688                    1                      0
# 1746943                    1                      0
# 2186790                    0                      0
# 1905712                    0                      0
# ...                      ...                    ...
# 2560053                    0                      1
# 2233224                    0                      0
# 1736506                    0                      0
# 3682165                    0                      0
# 4425504                    0                      0
#
# [98262 rows x 654 columns]

# %%
df_cat.columns
# Out:
# Index(['AIRLINE_AS', 'AIRLINE_B6', 'AIRLINE_DL', 'AIRLINE_EV', 'AIRLINE_F9',
#        'AIRLINE_HA', 'AIRLINE_MQ', 'AIRLINE_NK', 'AIRLINE_OO', 'AIRLINE_UA',
#        ...
#        'DESTINATION_AIRPORT_WYS', 'DESTINATION_AIRPORT_XNA',
#        'DESTINATION_AIRPORT_YAK', 'DESTINATION_AIRPORT_YUM',
#        'DAY_OF_WEEK_MONDAY', 'DAY_OF_WEEK_SATURDAY', 'DAY_OF_WEEK_SUNDAY',
#        'DAY_OF_WEEK_THURSDAY', 'DAY_OF_WEEK_TUESDAY', 'DAY_OF_WEEK_WEDNESDAY'],
#       dtype='object', length=654)

# %%
var_to_remove=["DAY_OF_WEEK","AIRLINE","ORIGIN_AIRPORT","DESTINATION_AIRPORT"]
df.drop(var_to_remove,axis=1,inplace=True)
df
# Out:
#          MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  \
# 3483269      8    5                 1120             -6.0       862
# 5476688     12    9                 1925              1.0      2475
# 1746943      4   22                  944             -3.0       874
# 2186790      5   19                 1325             13.0      1236
# 1905712      5    2                  540             -3.0       266
# ...        ...  ...                  ...              ...       ...
# 2560053      6   11                 1145             -7.0       271
# 2233224      5   22                  900              2.0      1222
# 1736506      4   21                 1545              0.0       237
# 3682165      8   17                  935             22.0       591
# 4425504     10    3                 1253             10.0       163
#
#          ARRIVAL_DELAY
# 3483269          -11.0
# 5476688          -41.0
# 1746943          -11.0
# 2186790          -13.0
# 1905712          -26.0
# ...                ...
# 2560053          -27.0
# 2233224            0.0
# 1736506            5.0
# 3682165            7.0
# 4425504           14.0
#
# [98262 rows x 6 columns]

# %%
data=pd.concat([df,df_cat],axis=1)
data
# Out:
#          MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  \
# 3483269      8    5                 1120             -6.0       862
# 5476688     12    9                 1925              1.0      2475
# 1746943      4   22                  944             -3.0       874
# 2186790      5   19                 1325             13.0      1236
# 1905712      5    2                  540             -3.0       266
# ...        ...  ...                  ...              ...       ...
# 2560053      6   11                 1145             -7.0       271
# 2233224      5   22                  900              2.0      1222
# 1736506      4   21                 1545              0.0       237
# 3682165      8   17                  935             22.0       591
# 4425504     10    3                 1253             10.0       163
#
#          ARRIVAL_DELAY  AIRLINE_AS  AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  ...  \
# 3483269          -11.0           0           0           0           0  ...
# 5476688          -41.0           0           0           1           0  ...
# 1746943          -11.0           0           0           1           0  ...
# 2186790          -13.0           0           0           0           0  ...
# 1905712          -26.0           0           0           0           0  ...
# ...                ...         ...         ...         ...         ...  ...
# 2560053          -27.0           0           0           1           0  ...
# 2233224            0.0           0           0           0           0  ...
# 1736506            5.0           0           0           1           0  ...
# 3682165            7.0           0           0           0           0  ...
# 4425504           14.0           0           0           0           0  ...
#
#          DESTINATION_AIRPORT_WYS  DESTINATION_AIRPORT_XNA  \
# 3483269                        0                        0
# 5476688                        0                        0
# 1746943                        0                        0
# 2186790                        0                        0
# 1905712                        0                        0
# ...                          ...                      ...
# 2560053                        0                        0
# 2233224                        0                        0
# 1736506                        0                        0
# 3682165                        0                        0
# 4425504                        0                        0
#
#          DESTINATION_AIRPORT_YAK  DESTINATION_AIRPORT_YUM  DAY_OF_WEEK_MONDAY  \
# 3483269                        0                        0                   0
# 5476688                        0                        0                   0
# 1746943                        0                        0                   0
# 2186790                        0                        0                   1
# 1905712                        0                        0                   0
# ...                          ...                      ...                 ...
# 2560053                        0                        0                   0
# 2233224                        0                        0                   0
# 1736506                        0                        0                   1
# 3682165                        0                        0                   0
# 4425504                        0                        0                   0
#
#          DAY_OF_WEEK_SATURDAY  DAY_OF_WEEK_SUNDAY  DAY_OF_WEEK_THURSDAY  \
# 3483269                     0                   0                     0
# 5476688                     0                   0                     0
# 1746943                     0                   0                     0
# 2186790                     0                   0                     0
# 1905712                     0                   0                     0
# ...                       ...                 ...                   ...
# 2560053                     0                   0                     0
# 2233224                     0                   0                     1
# 1736506                     0                   0                     0
# 3682165                     0                   1                     0
# 4425504                     0                   0                     0
#
#          DAY_OF_WEEK_TUESDAY  DAY_OF_WEEK_WEDNESDAY
# 3483269                    1                      0
# 5476688                    1                      0
# 1746943                    1                      0
# 2186790                    0                      0
# 1905712                    0                      0
# ...                      ...                    ...
# 2560053                    0                      1
# 2233224                    0                      0
# 1736506                    0                      0
# 3682165                    0                      0
# 4425504                    0                      0
#
# [98262 rows x 660 columns]

# %%
data.shape
# Out:
# (98262, 660)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
final_data = data.sample(n=60000)
final_data
X=final_data.drop("DEPARTURE_DELAY",axis=1)
Y=final_data.DEPARTURE_DELAY

# %%
final_data.shape
# Out:
# (60000, 660)

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor()
reg_rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = reg_rf.predict(X_test)

# %%
reg_rf.score(X_train,y_train)
# Out:
# 0.9898626108568217

# %%
reg_rf.score(X_test,y_test)
# Out:
# 0.9093656261415435

# %%
metrics.r2_score(y_test,y_pred)
# Out:
# 0.9093656261415435

# %%
pp=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
pp
# Out:
#          Actual  Predicted
# 5743677   125.0     114.62
# 5266451    -2.0      -4.38
# 3046083    58.0      32.54
# 1262935    -5.0      -5.70
# 2625357    54.0      23.87
# ...         ...        ...
# 2447700    39.0      10.30
# 2529088    -1.0      -4.04
# 4466991    -2.0      -5.48
# 5261795    -1.0      -5.69
# 3036555     9.0      16.11
#
# [12000 rows x 2 columns]

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 200, num = 12)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
min_samples_split = [2, 5, 10, 15, 100]
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
rf_random = RandomizedSearchCV(estimator = reg_rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=148; total time=   5.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=148; total time=   4.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=148; total time=   4.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=148; total time=   4.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=148; total time=   4.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=182; total time=   9.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=182; total time=   9.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=182; total time=   9.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=182; total time=   8.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=182; total time=   9.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=44; total time=  38.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=44; total time=  41.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=44; total time=  36.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=44; total time=  35.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=44; total time=  37.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=61; total time=  52.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=61; total time=  53.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=61; total time= 1.1min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=61; total time= 1.1min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=61; total time=  52.6s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=113; total time= 1.8min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=113; total time= 1.7min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=113; total time= 1.8min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=113; total time= 1.8min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=113; total time= 1.8min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=165; total time=  18.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=165; total time=  25.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=165; total time=  27.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=165; total time=  19.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=165; total time=  32.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=182; total time=  13.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=182; total time=   8.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=182; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=182; total time=   4.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=182; total time=   4.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=44; total time=   3.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=44; total time=   3.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=44; total time=   3.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=44; total time=   3.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=44; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=113; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=113; total time=   2.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=113; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=113; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=113; total time=   3.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=113; total time= 2.3min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=113; total time= 2.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=113; total time= 2.3min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=113; total time= 2.2min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=113; total time= 2.1min
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [10, 27, 44, 61, 79, 96,
#                                                          113, 130, 148, 165,
#                                                          182, 200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 61,
#  'min_samples_split': 5,
#  'min_samples_leaf': 5,
#  'max_features': 'auto',
#  'max_depth': 15}

# %%
p=rf_random.predict(X_test)

# %%
metrics.r2_score(y_test,p)
# Out:
# 0.9117143918218996

# %%
print('MAE:', metrics.mean_absolute_error(y_test,p))
print('MSE:', metrics.mean_squared_error(y_test,p))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,p)))
# Out:
# MAE: 6.133720025961622
# MSE: 113.05824887643347
# RMSE: 10.632885256431269

# %%
zz=pd.DataFrame({'Actual':y_test,'Predicted':p})
zz
# Out:
#          Actual   Predicted
# 5743677   125.0  111.908091
# 5266451    -2.0   -5.157444
# 3046083    58.0   32.852994
# 1262935    -5.0   -5.308056
# 2625357    54.0   34.332028
# ...         ...         ...
# 2447700    39.0   14.191068
# 2529088    -1.0   -3.786759
# 4466991    -2.0   -4.130125
# 5261795    -1.0   -6.167014
# 3036555     9.0   17.114193
#
# [12000 rows x 2 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(random_state=0)

# %%
GBR=gbr.fit(X_train,y_train)
pre=GBR.predict(X_test)

# %%
metrics.r2_score(y_test,pre)
# Out:
# 0.9143332551359775

# %%
gg=pd.DataFrame({'Actual':y_test,'Predicted':pre})
gg
# Out:
#          Actual   Predicted
# 5743677   125.0  116.021653
# 5266451    -2.0   -5.354448
# 3046083    58.0   29.940262
# 1262935    -5.0   -3.229531
# 2625357    54.0   33.421899
# ...         ...         ...
# 2447700    39.0   11.172480
# 2529088    -1.0   -2.977581
# 4466991    -2.0   -2.793321
# 5261795    -1.0   -4.548163
# 3036555     9.0   20.734256
#
# [12000 rows x 2 columns]

# %%
def predict(MONTH, DAY,SCHEDULED_DEPARTURE,DISTANCE, ARRIVAL_DELAY,AIRLINE,ORIGIN_AIRPORT,DESTINATION_AIRPORT,DAY_OF_WEEK):
    AIRLINE_index = np.where(X.columns==AIRLINE)[0][0]
    ORIGIN_index = np.where(X.columns==ORIGIN_AIRPORT)[0][0]
    DESTINATION_index = np.where(X.columns==DESTINATION_AIRPORT)[0][0]
    DAY_OF_WEEK_index = np.where(X.columns==DAY_OF_WEEK)[0][0]
    x= np.zeros(len(X.columns))
    x[0] = MONTH
    x[1] = DAY
    x[2] = SCHEDULED_DEPARTURE
    x[3] = DISTANCE
    x[4] = ARRIVAL_DELAY
    if AIRLINE_index >=0:
        x[AIRLINE_index] = 1
    if ORIGIN_index >=0:
        x[ORIGIN_index] = 1
    if DESTINATION_index >=0:
        x[DESTINATION_index] = 1
    if  DAY_OF_WEEK_index >= 0:
        x[ DAY_OF_WEEK_index] = 1

    return gbr.predict([x])[0]

# %%
res= predict(5,6,1515,328,-8.0,'AIRLINE_OO','ORIGIN_AIRPORT_PHX','DESTINATION_AIRPORT_ABQ','DAY_OF_WEEK_TUESDAY')
print("Delay :",res)
if(res<=-15):
  print("Flight is delayed")
else:
  print("Flight is not delayed")
# Out:
# Delay : -4.290298347198289
# Flight is not delayed

# %%
import joblib

# %%
f = "C:/Users/HARISUDHAN/Documents/model.pkl"
joblib.dump(gbr,f)
# Out:
# ['C:/Users/HARISUDHAN/Documents/model.pkl']
